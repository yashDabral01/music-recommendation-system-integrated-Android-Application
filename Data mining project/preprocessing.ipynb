# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#        Unnamed: 0            track_id                 name  \
# 0               0  TRIOREW128F424EAF0       Mr. Brightside
# 1               1  TRRIVDJ128F429B0E8           Wonderwall
# 2               4  TRLNZBD128F935E4D8                Creep
# 3               7  TRUMISQ128F9340BEE     Somebody Told Me
# 4               9  TRXOGZT128F424AD74         Karma Police
# ...           ...                 ...                  ...
# 11178       21010  TRXHNGM128E07836CC            Open Eyes
# 11179       21011  TRNDEMF128F9314E78              3 Rings
# 11180       21012  TRLODOZ128EF362FC0  Rise From The Ashes
# 11181       21013  TROHNAJ128F145AFF7     Bring It On Down
# 11182       21014  TRHQCSH128F42724B7   Colors Of The Wind
#
#                    artist_x  \
# 0               The Killers
# 1                     Oasis
# 2                 Radiohead
# 3               The Killers
# 4                 Radiohead
# ...                     ...
# 11178             For Today
# ...

# %%
df = df.drop(df.columns[0],axis=1)
df
# Out:
#                  track_id                 name              artist_x  \
# 0      TRIOREW128F424EAF0       Mr. Brightside           The Killers
# 1      TRRIVDJ128F429B0E8           Wonderwall                 Oasis
# 2      TRLNZBD128F935E4D8                Creep             Radiohead
# 3      TRUMISQ128F9340BEE     Somebody Told Me           The Killers
# 4      TRXOGZT128F424AD74         Karma Police             Radiohead
# ...                   ...                  ...                   ...
# 11178  TRXHNGM128E07836CC            Open Eyes             For Today
# 11179  TRNDEMF128F9314E78              3 Rings    Insane Clown Posse
# 11180  TRLODOZ128EF362FC0  Rise From The Ashes           War Of Ages
# 11181  TROHNAJ128F145AFF7     Bring It On Down  Boom Boom Satellites
# 11182  TRHQCSH128F42724B7   Colors Of The Wind               ACIDMAN
#
#                                      spotify_preview_url  \
# 0      https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# ...

# %%
df.drop(['genre','liveness','tags','danceability', 'energy','key','loudness','mode','speechiness','acousticness','instrumentalness','valence','tempo','time_signature','artist_y','link'], axis=1, inplace=True)
df
# Out:
#                  track_id                 name              artist_x  \
# 0      TRIOREW128F424EAF0       Mr. Brightside           The Killers
# 1      TRRIVDJ128F429B0E8           Wonderwall                 Oasis
# 2      TRLNZBD128F935E4D8                Creep             Radiohead
# 3      TRUMISQ128F9340BEE     Somebody Told Me           The Killers
# 4      TRXOGZT128F424AD74         Karma Police             Radiohead
# ...                   ...                  ...                   ...
# 11178  TRXHNGM128E07836CC            Open Eyes             For Today
# 11179  TRNDEMF128F9314E78              3 Rings    Insane Clown Posse
# 11180  TRLODOZ128EF362FC0  Rise From The Ashes           War Of Ages
# 11181  TROHNAJ128F145AFF7     Bring It On Down  Boom Boom Satellites
# 11182  TRHQCSH128F42724B7   Colors Of The Wind               ACIDMAN
#
#                                      spotify_preview_url  \
# 0      https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# ...

# %%
df.columns = ['track_id','song_name','artist_name','preview_url','spotify_id','release_year','duration_ms','lyrics']
df
# Out:
#                  track_id            song_name           artist_name  \
# 0      TRIOREW128F424EAF0       Mr. Brightside           The Killers
# 1      TRRIVDJ128F429B0E8           Wonderwall                 Oasis
# 2      TRLNZBD128F935E4D8                Creep             Radiohead
# 3      TRUMISQ128F9340BEE     Somebody Told Me           The Killers
# 4      TRXOGZT128F424AD74         Karma Police             Radiohead
# ...                   ...                  ...                   ...
# 11178  TRXHNGM128E07836CC            Open Eyes             For Today
# 11179  TRNDEMF128F9314E78              3 Rings    Insane Clown Posse
# 11180  TRLODOZ128EF362FC0  Rise From The Ashes           War Of Ages
# 11181  TROHNAJ128F145AFF7     Bring It On Down  Boom Boom Satellites
# 11182  TRHQCSH128F42724B7   Colors Of The Wind               ACIDMAN
#
#                                              preview_url  \
# 0      https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# ...

# %%
df.to_csv("cleaned_data.csv",index=False)
